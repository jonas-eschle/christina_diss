# %%
import pandas as pd

# %% [markdown]
# TODO: check if number is correct, update

# %%
df = pd.read_excel('data_all.xlsx')

# %%
df.columns
# Out:
# Index(['Pat.Nr.', 'Name', 'Geburtsdatum', 'Datum', 'Befund', 'Unnamed: 5',
#        'Betrifft:', 'Datum_1', 'Befund_1', 'Unnamed: 9', 'Betrifft:_1',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15'],
#       dtype='object')

# %%
df = df.drop('Geburtsdatum', axis='columns')

# %%
colreasonsel1 = df['Pat.Nr.'].apply(lambda x: isinstance(x, str))

# %%
colreason1 = df.loc[colreasonsel1].rename({'Pat.Nr.': 'reason'}, axis='columns')

# %%
colreason1
# Out:
#                                                  reason        Name  \
# 67                                         nicht im T&E         NaN
# 1917                                       nicht im T&E         NaN
# 2104                                           kein T&E         NaN
# 4795                       MÖ im Rahmen Grunderkrankung         NaN
# 5732                               zugewiesen; kein T&E         NaN
# 6497                                        nicht bilat      Riehen
# 7711   wird ab 3.8.17 plötzlich bds unter ZVV gespritzt         NaN
# 7712                              vorher R: AMD, L: ZVV         NaN
# 7713                     >mehrere Diagnosen oder nicht?         NaN
# 9777                        Label R zuerst ZVV dann AMD         NaN
# 10274  Diagnose am linken Auge wechselt von ZVV auf AMD         NaN
# 12504                  R wechselt Label von VAV auf AMD         NaN
# 24317                                          Bayer AG  Test, Otto
#
# ...

# %%
colreason2 = df.loc[df['Name'].apply(lambda x: isinstance(x, str) and not ',' in x and not 'Dr.' in x)].rename({'Name': 'reason'}, axis='columns')

# %%
colreason2
# Out:
#       Pat.Nr.                        reason               Datum Befund  \
# 3         NaN                           DMÖ 2019-09-03 14:56:00     IV
# 4         NaN                  nicht im T&E 2019-07-04 14:10:00     IV
# 19        NaN                           DMÖ 2016-01-25 17:51:00     IV
# 20        NaN  parallel in Türkei behandelt 2015-08-04 09:37:00     IV
# 96        NaN                  nicht im T&E 2017-05-15 14:53:00     IV
# ...       ...                           ...                 ...    ...
# 26989     NaN                            ZH 2016-06-07 15:38:00     IV
# 27012     NaN                            ZH 2019-04-09 14:31:00     IV
# 27039     NaN                            ZH 2019-09-24 14:21:00     IV
# 27084     NaN           Visus nicht messbar 2020-02-03 10:58:00     IV
# 27090     NaN                            ZH 2019-12-16 12:51:00     IV
#
#       Unnamed: 5 Betrifft:              Datum_1 Befund_1 Unnamed: 9  \
# ...

# %%
colreason = pd.concat([colreason1, colreason2])

# %%
colreason
# Out:
#                              reason Name               Datum Befund  \
# 67                     nicht im T&E  NaN 2017-07-31 14:23:00     IV
# 1917                   nicht im T&E  NaN 2019-06-03 18:00:00     IV
# 2104                       kein T&E  NaN 2019-01-28 11:18:00     IV
# 4795   MÖ im Rahmen Grunderkrankung  NaN 2018-12-13 11:19:00    NaN
# 5732           zugewiesen; kein T&E  NaN 2019-11-26 16:51:00     IV
# ...                             ...  ...                 ...    ...
# 26989                            ZH  NaN 2016-06-07 15:38:00     IV
# 27012                            ZH  NaN 2019-04-09 14:31:00     IV
# 27039                            ZH  NaN 2019-09-24 14:21:00     IV
# 27084           Visus nicht messbar  NaN 2020-02-03 10:58:00     IV
# 27090                            ZH  NaN 2019-12-16 12:51:00     IV
#
#       Unnamed: 5 Betrifft:              Datum_1 Befund_1 Unnamed: 9  \
# 67           EYL         R  2018-05-23 11:14:00       IV        EYL
# ...

# %%
from collections import Counter

# %%
invalid = ['Zurich',
'Liestal',
'Delémont',
          "Ozurdex Treatment"]

# %%
counted_reasons = Counter(colreason['reason'])
counted_reasons
# Out:
# Counter({'ZH': 582,
#          'kein T&E': 57,
#          'nicht bilateral': 51,
#          'Liestal': 40,
#          'nur 1x bilateral': 30,
#          'ZH: nicht im T&E': 26,
#          'nicht im T&E': 10,
#          'nicht bilat': 10,
#          'Delémont': 5,
#          'OZU': 5,
#          'Laufen': 4,
#          'nicht im Beobachtungszeitraum': 4,
#          'Visus nicht messbar': 4,
#          'zugewiesen kein T&E': 3,
#          'DMÖ': 2,
#          'VD ZH --> keine T&E': 2,
#          'Fleischlin/Jesse Liestal': 2,
#          'keine bilaterale IVI': 2,
#          'IVI Delémont': 2,
#          'keine bilat T&E': 2,
#          'Riehen': 2,
#          'keine bilateralen IVIs': 2,
#          'Zuweiser T&E': 2,
#          'nur einmal bilateral': 2,
#          'MÖ im Rahmen Grunderkrankung': 1,
#          'zugewiesen; kein T&E': 1,
#          'wird ab 3.8.17 plötzlich bds unter ZVV gespritzt': 1,
#          'vorher R: AMD, L: ZVV': 1,
# ...

# %%
counter_asdict = {'ZH': 582,
         'kein T&E': 57,
         'nicht bilateral': 51,
         'Liestal': 40,
         'nur 1x bilateral': 30,
         'ZH: nicht im T&E': 26,
         'nicht im T&E': 10,
         'nicht bilat': 10,
         'Delémont': 5,
         'OZU': 5,
         'Laufen': 4,
         'nicht im Beobachtungszeitraum': 4,
         'Visus nicht messbar': 4,
         'zugewiesen kein T&E': 3,
         'DMÖ': 2,
         'VD ZH --> keine T&E': 2,
         'Fleischlin/Jesse Liestal': 2,
         'keine bilaterale IVI': 2,
         'IVI Delémont': 2,
         'keine bilat T&E': 2,
         'Riehen': 2,
         'keine bilateralen IVIs': 2,
         'Zuweiser T&E': 2,
         'nur einmal bilateral': 2,
         'MÖ im Rahmen Grunderkrankung': 1,
         'zugewiesen; kein T&E': 1,
         'wird ab 3.8.17 plötzlich bds unter ZVV gespritzt': 1,
         'vorher R: AMD, L: ZVV': 1,
         '>mehrere Diagnosen oder nicht?': 1,
         'Label R zuerst ZVV dann AMD': 1,
         'Diagnose am linken Auge wechselt von ZVV auf AMD': 1,
         'R wechselt Label von VAV auf AMD': 1,
         'Bayer AG': 1,
         'parallel in Türkei behandelt': 1,
         'Keskinaslan-Pat': 1,
         'Feld BG besprechen': 1,
         'ausgeschlossen bei 1xbilat IVI bds PRN': 1,
         'St.n. Hospitalisation weg. Sturz': 1,
         'Vitientransplantation': 1,
         'CVI vor 2 WO': 1,
         'Jesse/Fleischlin Liestal': 1,
         'bilaterale IVI nur Luc+OZUrdex': 1,
         '10.06.15 FK-Gefühl+Augenbrennen': 1,
         'BH injektion + HH Stippung': 1,
         '> SICCA': 1,
         'nicht im T&E bei bilateralen IVI': 1,
         'OZUrdex': 1,
         'nur einmal bilateral im PRN bds': 1,
         'ab hier: Zuweiser T&E': 1,
         '10.05.16 VAV': 1,
         'Liestal: Fleischlin': 1,
         'keine bilat': 1,
         'Mouches bilateral nach IVI': 1,
         'keine Visusmessung möglich': 1,
         'ZVV bds von anfangan': 1,
         'r bleibt ZVV': 1,
         'kein T&E; Riehen': 1,
         'links auch AMD von Anfang an': 1,
         'einmal links unter ZVV gespritzt am 29.03.16': 1,
         'sonst unter DMÖ': 1,
         'siehe auch Beurteilung vom 27.04.16': 1,
         'bds DMÖ': 1,
         'MusterKG': 1,
         'direkter loss to follow up nach einmaliger bilateraler IVI': 1,
         'AMD bds': 1,
         'nur einmal injiziert': 1,
         'nur bilateral mit OZUrdex': 1,
         'Zuweiser T&E ohne Follow-up': 1,
         'Pat mit nur einer bilateralen Injektion im Dez 19': 1,
         'Visus links nicht messbar': 1,
         'nur eine bilaterale IVI': 1,
         'Wieso wird das rechte Auge schlussendlich im PRN schema gespritzt?': 1,
         'keine der Grundindikationen': 1,
         'kein regelmässiges T&E da Zuweiser': 1,
         'OZU = Ende Beobachtungszeitraum bds oder nur links?': 1,
         'Pat klagt über Hörminderung bds und Tinnitus nach bilateraler Ozurdex und Eylea injektion > vlt doch bds Beobachtungszeitraum stoppen?': 1,
         'keine 2x T&E bilateral': 1,
         'Visus nicht mehr messbar': 1,
         'Kein T&E': 1,
         'nur Ozurdex': 1,
         'kein T&E bei bilateraler IVI': 1,
         'kein T&E ': 1,
         'kein T&E bilateral': 1,
         'nur 1x bilateral im T&E': 1,
         'unklarer Indikationsdiagnose': 1,
         'Zuweiser T&E nur 1x bilateral': 1,
         'label ZVV bds; mit KH besprochen': 1,
         'keine bilaterale T&E': 1,
         'Zh': 1}

# %%
rename_reasons = {
    # Location references
    'ZH': 'Zurich',
    'Zh': 'Zurich',
    'Liestal': 'Liestal',
    'Delémont': 'Delémont',
    'Laufen': 'Liestal',
    'Riehen': 'Liestal',
    'Fleischlin/Jesse Liestal': 'Liestal',
    'Jesse/Fleischlin Liestal': 'Liestal',
    'Liestal: Fleischlin': 'Liestal',
    
    # Treatment Protocol Status
    'kein T&E': 'No T&E',
    'nicht im T&E': 'No T&E',
    'ZH: nicht im T&E': 'Zurich',
    'zugewiesen kein T&E': 'Referrer T&E',
    'zugewiesen; kein T&E': 'Referrer T&E',
    'VD ZH --> keine T&E': 'Zurich',
    'kein T&E bei bilateraler IVI': 'No T&E',
    'nicht im T&E bei bilateralen IVI': 'No T&E',
    'kein T&E bilateral': 'No T&E',
    'kein T&E ': 'No T&E',
    'Kein T&E': 'No T&E',
    'kein T&E; Riehen': 'Liestal',
    'kein regelmässiges T&E da Zuweiser': 'No T&E',
    'keine bilaterale T&E': 'No T&E',
    'keine 2x T&E bilateral': 'No T&E',
    'nur 1x bilateral im T&E': 'No T&E',
    
    # Bilateral Treatment Status
    'nicht bilateral': 'No Bilateral',
    'nicht bilat': 'No Bilateral',
    'keine bilaterale IVI': 'No Bilateral',
    'keine bilateralen IVIs': 'No Bilateral',
    'keine bilat T&E': 'No T&E',
    'keine bilat': 'No Bilateral',
    'nur 1x bilateral': 'Single bilat',
    'nur einmal bilateral': 'Single bilat',
    'nur einmal bilateral im PRN bds': 'Single bilat',
    'ausgeschlossen bei 1xbilat IVI bds PRN': 'Single bilat',
    'direkter loss to follow up nach einmaliger bilateraler IVI': 'Lost to Follow-up',
    'Pat mit nur einer bilateralen Injektion im Dez 19': 'Single bilat',
    'nur eine bilaterale IVI': 'Single bilat',
    
    # Medical Conditions and Diagnostics
    'DMÖ': 'DME',
    'bds DMÖ': 'DME botheye',
    'MÖ im Rahmen Grunderkrankung': 'ME',
    'OZU': 'Ozurdex Treatment',
    'OZUrdex': 'Ozurdex Treatment',
    'nur Ozurdex': 'Ozurdex Treatment',
    'bilaterale IVI nur Luc+OZUrdex': 'Ozurdex Treatment',
    'nur bilateral mit OZUrdex': 'Ozurdex Treatment',
    'Visus nicht messbar': 'Visual Acuity Not Measurable',
    'keine Visusmessung möglich': 'Visual Acuity Not Measurable',
    'Visus links nicht messbar': 'Visual Acuity Not Measurable',
    'Visus nicht mehr messbar': 'Visual Acuity Not Measurable',
    'AMD bds': 'AMD Both Eyes',
    'ZVV bds von anfangan': 'ZVV Both Eyes From Start',
    'r bleibt ZVV': 'Right Eye Remains ZVV',
    'sonst unter DMÖ': 'Otherwise Under DME',
    'unklarer Indikationsdiagnose': 'Unclear Indication Diagnosis',
    'label ZVV bds; mit KH besprochen': 'ZVV Both Eyes Label Discussed with Hospital',
    
    # Medication/Treatment Records
    'IVI Delémont': 'Delémont',
    'BH injektion + HH Stippung': 'BH Injection and HH Stippling',  # ?
    
    # Patient Status Notes
    'nicht im Beobachtungszeitraum': 'Not in Observation Period',
    'Zuweiser T&E': 'Referrer T&E',
    'ab hier: Zuweiser T&E': 'Referrer T&E',
    'Zuweiser T&E ohne Follow-up': 'Referrer T&E',
    'Zuweiser T&E nur 1x bilateral': 'Referrer T&E',
    'parallel in Türkei behandelt': 'Lost to Follow-up',
    'St.n. Hospitalisation weg. Sturz': 'Lost to Follow-up',
    'keine der Grundindikationen': 'None of the Basic Indications',
    'Mouches bilateral nach IVI': 'Bilateral Floaters After IVI',
    'Bayer AG': 'Bayer AG',
    'MusterKG': 'Sample Medical Record',
    
    # Special Case Notes
    'wird ab 3.8.17 plötzlich bds unter ZVV gespritzt': 'Sudden ZVV Injection Both Eyes from 3.8.17',
    'vorher R: AMD, L: ZVV': 'Previously Right: AMD, Left: ZVV',
    '>mehrere Diagnosen oder nicht?': 'Multiple Diagnoses Or Not?',
    'Label R zuerst ZVV dann AMD': 'Right Label First ZVV Then AMD',
    'Diagnose am linken Auge wechselt von ZVV auf AMD': 'Left Eye Diagnosis Changes from ZVV to AMD',
    'R wechselt Label von VAV auf AMD': 'Right Eye Label Changes from VAV to AMD',
    'Keskinaslan-Pat': 'Referrer T&E',
    'Feld BG besprechen': 'Discuss BG Field',
    'Vitientransplantation': 'Vitreous Transplantation',
    'CVI vor 2 WO': 'CVI 2 Weeks Ago',
    '10.06.15 FK-Gefühl+Augenbrennen': 'Foreign Body Sensation and Eye Burning on 10.06.15',
    '> SICCA': 'Dry Eye Syndrome',
    '10.05.16 VAV': 'VAV on 10.05.16',
    'links auch AMD von Anfang an': 'Left Eye Also AMD From Beginning',
    'einmal links unter ZVV gespritzt am 29.03.16': 'Left Eye Injected Under ZVV on 29.03.16',
    'siehe auch Beurteilung vom 27.04.16': 'See Also Assessment from 27.04.16',
    'nur einmal injiziert': 'Single bilat',
    'Wieso wird das rechte Auge schlussendlich im PRN schema gespritzt?': 'Why Is Right Eye Eventually Injected in PRN Scheme?',
    'OZU = Ende Beobachtungszeitraum bds oder nur links?': 'Ozurdex = End of Observation Period Both Eyes or Left Only?',
    'Pat klagt über Hörminderung bds und Tinnitus nach bilateraler Ozurdex und Eylea injektion > vlt doch bds Beobachtungszeitraum stoppen?': 'Patient Complains of Bilateral Hearing Loss and Tinnitus After Bilateral Ozurdex and Eylea Injection, Perhaps Stop Observation Period for Both Eyes?'
}

# %%
from collections import defaultdict
new_reason = defaultdict(lambda: 0)

# %%
for reason, count in counted_reasons.items():
    new_reason[rename_reasons[reason]] += count

# %%
new_reason
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'No T&E': 78,
#              'ME': 1,
#              'Referrer T&E': 10,
#              'No Bilateral': 66,
#              'Sudden ZVV Injection Both Eyes from 3.8.17': 1,
#              'Previously Right: AMD, Left: ZVV': 1,
#              'Multiple Diagnoses Or Not?': 1,
#              'Right Label First ZVV Then AMD': 1,
#              'Left Eye Diagnosis Changes from ZVV to AMD': 1,
#              'Right Eye Label Changes from VAV to AMD': 1,
#              'Bayer AG': 1,
#              'DME': 2,
#              'Lost to Follow-up': 3,
#              'Zurich': 611,
#              'Discuss BG Field': 1,
#              'Single bilat': 37,
#              'Vitreous Transplantation': 1,
#              'CVI 2 Weeks Ago': 1,
#              'Liestal': 51,
#              'Ozurdex Treatment': 9,
#              'Foreign Body Sensation and Eye Burning on 10.06.15': 1,
#              'BH Injection and HH Stippling': 1,
# ...

# %%
{k: v for k, v in sorted(new_reason.items(), key=lambda item: item[1], reverse=True)}
# Out:
# {'Zurich': 611,
#  'No T&E': 78,
#  'No Bilateral': 66,
#  'Liestal': 51,
#  'Single bilat': 37,
#  'Referrer T&E': 10,
#  'Ozurdex Treatment': 9,
#  'Delémont': 7,
#  'Visual Acuity Not Measurable': 7,
#  'Not in Observation Period': 4,
#  'Lost to Follow-up': 3,
#  'DME': 2,
#  'ME': 1,
#  'Sudden ZVV Injection Both Eyes from 3.8.17': 1,
#  'Previously Right: AMD, Left: ZVV': 1,
#  'Multiple Diagnoses Or Not?': 1,
#  'Right Label First ZVV Then AMD': 1,
#  'Left Eye Diagnosis Changes from ZVV to AMD': 1,
#  'Right Eye Label Changes from VAV to AMD': 1,
#  'Bayer AG': 1,
#  'Discuss BG Field': 1,
#  'Vitreous Transplantation': 1,
#  'CVI 2 Weeks Ago': 1,
#  'Foreign Body Sensation and Eye Burning on 10.06.15': 1,
#  'BH Injection and HH Stippling': 1,
#  'Dry Eye Syndrome': 1,
#  'VAV on 10.05.16': 1,
#  'Bilateral Floaters After IVI': 1,
#  'ZVV Both Eyes From Start': 1,
#  'Right Eye Remains ZVV': 1,
#  'Left Eye Also AMD From Beginning': 1,
# ...

# %%
tot_invalid = sum([v for k, v in new_reason.items() if k in invalid])

# %%
tot_invalid
# Out:
# 678

# %%
df
# Out:
#       Pat.Nr.            Name               Datum Befund Unnamed: 5 Betrifft:  \
# 0      441119   Abiriga, Elsa 2016-10-25 15:40:00     IV        LUC         R
# 1         NaN             NaN 2016-09-27 16:56:00     IV        LUC         R
# 2      201117  Acampora, Ciro 2020-03-18 14:10:00     IV        EYL         R
# 3         NaN             DMÖ 2019-09-03 14:56:00     IV        EYL         R
# 4         NaN    nicht im T&E 2019-07-04 14:10:00     IV        EYL         R
# ...       ...             ...                 ...    ...        ...       ...
# 27125     NaN             NaN                 NaT    NaN        NaN       NaN
# 27126     NaN             NaN                 NaT    NaN        NaN       NaN
# 27127     NaN             NaN                 NaT    NaN        NaN       NaN
# 27128     NaN             NaN                 NaT    NaN        NaN       NaN
# 27129     NaN             NaN                 NaT    NaN        NaN       NaN
#
# ...

# %%
npatients = (~df['Pat.Nr.'].isna()).sum()
npatients
# Out:
# np.int64(1578)

# %%
tot_binningen = npatients - tot_invalid
tot_binningen
# Out:
# np.int64(900)

# %%
tot_valid = 428

# %%
tot_invalid_binningen = tot_binningen - tot_valid

# %%
tot_invalid_binningen
# Out:
# np.int64(472)

# %%
new_reasons_bin = {k: v for k, v in new_reason.items() if k not in invalid}

# %%
new_reason_bin = {k: v for k, v in sorted(new_reasons_bin.items(), key=lambda item: item[1], reverse=True)}

# %%
new_reason_bin_percent = {k: (v, f'{int(v / tot_invalid_binningen * 100)}%') for k, v in new_reason_bin.items()}

# %%
new_reason_bin_percent
# Out:
# {'No T&E': (78, '16%'),
#  'No Bilateral': (66, '13%'),
#  'Single bilat': (37, '7%'),
#  'Referrer T&E': (10, '2%'),
#  'Visual Acuity Not Measurable': (7, '1%'),
#  'Not in Observation Period': (4, '0%'),
#  'Lost to Follow-up': (3, '0%'),
#  'DME': (2, '0%'),
#  'ME': (1, '0%'),
#  'Sudden ZVV Injection Both Eyes from 3.8.17': (1, '0%'),
#  'Previously Right: AMD, Left: ZVV': (1, '0%'),
#  'Multiple Diagnoses Or Not?': (1, '0%'),
#  'Right Label First ZVV Then AMD': (1, '0%'),
#  'Left Eye Diagnosis Changes from ZVV to AMD': (1, '0%'),
#  'Right Eye Label Changes from VAV to AMD': (1, '0%'),
#  'Bayer AG': (1, '0%'),
#  'Discuss BG Field': (1, '0%'),
#  'Vitreous Transplantation': (1, '0%'),
#  'CVI 2 Weeks Ago': (1, '0%'),
#  'Foreign Body Sensation and Eye Burning on 10.06.15': (1, '0%'),
#  'BH Injection and HH Stippling': (1, '0%'),
#  'Dry Eye Syndrome': (1, '0%'),
#  'VAV on 10.05.16': (1, '0%'),
#  'Bilateral Floaters After IVI': (1, '0%'),
# ...
