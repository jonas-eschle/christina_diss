# %%
import pandas as pd

# %%
df = pd.read_excel("data_all.xlsx")

# %%
df
# Out:
#       Pat.Nr.            Name         Geburtsdatum               Datum Befund  \
# 0      441119   Abiriga, Elsa  1931-07-30 00:00:00 2016-10-25 15:40:00     IV
# 1         NaN             NaN                  NaN 2016-09-27 16:56:00     IV
# 2      201117  Acampora, Ciro  1949-05-22 00:00:00 2020-03-18 14:10:00     IV
# 3         NaN             DMÖ                  NaN 2019-09-03 14:56:00     IV
# 4         NaN    nicht im T&E                  NaN 2019-07-04 14:10:00     IV
# ...       ...             ...                  ...                 ...    ...
# 27125     NaN             NaN                  NaN                 NaT    NaN
# 27126     NaN             NaN                  NaN                 NaT    NaN
# 27127     NaN             NaN                  NaN                 NaT    NaN
# 27128     NaN             NaN                  NaN                 NaT    NaN
# 27129     NaN             NaN                  NaN                 NaT    NaN
#
# ...

# %%
df.
